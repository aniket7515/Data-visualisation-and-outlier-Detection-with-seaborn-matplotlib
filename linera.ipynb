# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,20,1000)

# %%
m,c=3,10
y=m*x+c
plt.scatter(x,y)

# %%
noise=np.random.randn(1000)*5
y_mod=y+noise

# %%
plt.scatter(x,y_mod)

# %%
x=np.random.randn(10000)
plt.hist(x,bins=120)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   0.,   1.,   2.,   0.,   1.,
#           1.,   1.,   0.,   1.,   1.,   3.,   3.,   5.,   4.,   6.,   7.,
#           8.,   7.,  17.,  20.,   9.,  23.,  30.,  20.,  31.,  31.,  39.,
#          45.,  49.,  61.,  47.,  67.,  71.,  88.,  79., 122., 110., 106.,
#         144., 155., 165., 149., 154., 207., 172., 207., 214., 211., 220.,
#         259., 220., 254., 233., 262., 236., 270., 259., 258., 277., 267.,
#         250., 248., 241., 255., 222., 214., 216., 204., 188., 167., 172.,
#         159., 136., 117., 143., 123., 124., 118.,  79.,  72.,  80.,  72.,
#          59.,  50.,  40.,  59.,  38.,  29.,  34.,  33.,  20.,  20.,  17.,
#          19.,   9.,   9.,   8.,   6.,  10.,   4.,   8.,   2.,   2.,   3.,
#           0.,   0.,   3.,   4.,   0.,   0.,   1.,   1.,   1.,   1.]),
#  array([-4.14174635, -4.07554785, -4.00934934, -3.94315084, -3.87695233,
#         -3.81075383, -3.74455533, -3.67835682, -3.61215832, -3.54595982,
#         -3.47976131, -3.41356281, -3.34736431, -3.2811658 , -3.2149673 ,
#         -3.1487688 , -3.08257029, -3.01637179, -2.95017329, -2.88397478,
#         -2.81777628, -2.75157778, -2.68537927, -2.61918077, -2.55298227,
#         -2.48678376, -2.42058526, -2.35438675, -2.28818825, -2.22198975,
#         -2.15579124, -2.08959274, -2.02339424, -1.95719573, -1.89099723,
#         -1.82479873, -1.75860022, -1.69240172, -1.62620322, -1.56000471,
#         -1.49380621, -1.42760771, -1.3614092 , -1.2952107 , -1.2290122 ,
#         -1.16281369, -1.09661519, -1.03041668, -0.96421818, -0.89801968,
#         -0.83182117, -0.76562267, -0.69942417, -0.63322566, -0.56702716,
#         -0.50082866, -0.43463015, -0.36843165, -0.30223315, -0.23603464,
#         -0.16983614, -0.10363764, -0.03743913,  0.02875937,  0.09495787,
#          0.16115638,  0.22735488,  0.29355339,  0.35975189,  0.42595039,
#          0.4921489 ,  0.5583474 ,  0.6245459 ,  0.69074441,  0.75694291,
#          0.82314141,  0.88933992,  0.95553842,  1.02173692,  1.08793543,
#          1.15413393,  1.22033243,  1.28653094,  1.35272944,  1.41892794,
#          1.48512645,  1.55132495,  1.61752346,  1.68372196,  1.74992046,
#          1.81611897,  1.88231747,  1.94851597,  2.01471448,  2.08091298,
#          2.14711148,  2.21330999,  2.27950849,  2.34570699,  2.4119055 ,
#          2.478104  ,  2.5443025 ,  2.61050101,  2.67669951,  2.74289801,
#          2.80909652,  2.87529502,  2.94149353,  3.00769203,  3.07389053,
#          3.14008904,  3.20628754,  3.27248604,  3.33868455,  3.40488305,
#          3.47108155,  3.53728006,  3.60347856,  3.66967706,  3.73587557,
#          3.80207407]),
#  <BarContainer object of 120 artists>)

# %%
plt.pie([10,20,30],explode=[0,.1,0],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x26265316e80>,
#   <matplotlib.patches.Wedge at 0x26265323580>,
#   <matplotlib.patches.Wedge at 0x26265323c40>],
#  [Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(-0.6000000648665187, 1.0392304470906217, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
x=np.random.randn(1000)
sns.displot(x,bins=30)

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data["total_bill"],data["tip"],hue=data["smoker"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
from sklearn.datasets import load_boston

# %%
X,y=load_boston(return_X_y=True)
sns.violinplot(y=y)
# Out:
# <AxesSubplot:>
